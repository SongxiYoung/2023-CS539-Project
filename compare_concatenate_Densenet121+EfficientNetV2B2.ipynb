# %% [markdown]
# ## [1. Import Needed Modules](#import) ##
# ## [2. Read in images and create a dataframe of image paths and class labels](#makedf) ##
# ## [3. Create train, test and validation generators](#generators) ##
# ## [4. Create a function to show Training Image Samples](#show) ##
# ## [5. Create the Model](#model) ##
# ## [6. Create a custom Keras callback to continue or halt training](#callback) ##
# ## [7. Instantiate custom callback and create callbacks to control learning rate and early stopping](#callbacks) ##
# ## [8. Train the model](#train) ##
# ## [9. Define a function to plot the training data](#plot) ##
# ## [10. Make predictions on test set, create Confusion Matrix and Classification Report](#result) ##
# ## [11 Save the model](#save) ##
# ## [12 Plot Validation Loss % change between epochs](#implot) ##
# ## [13 Analysis of the Validation Loss % change plot](#analysis) ##

# %% [markdown]
# <a id="import"></a>
# # <center>Import Need Modules</center>

# %%
import numpy as np
import pandas as pd
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import time
import matplotlib.pyplot as plt
import cv2
import seaborn as sns
sns.set_style('darkgrid')
import shutil
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Activation,Dropout,Conv2D, MaxPooling2D,BatchNormalization, Flatten
from tensorflow.keras.optimizers import Adam, Adamax, AdamW
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras import regularizers
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras import layers
import time
import glob
# !pip install -U tensorflow-addons
# !pip install vit-keras
from vit_keras import vit, utils, visualize
# Out:
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (612 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 612.3/612.3 kB 8.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (23.2)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow-addons
# Successfully installed tensorflow-addons-0.22.0 typeguard-2.13.3
# Collecting vit-keras
#   Downloading vit_keras-0.1.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from vit-keras) (1.11.3)
# Collecting validators (from vit-keras)
#   Downloading validators-0.22.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from scipy->vit-keras) (1.23.5)
# Installing collected packages: validators, vit-keras
# Successfully installed validators-0.22.0 vit-keras-0.1.2
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
from google.colab import drive

drive.mount('/content/drive')

#lets see how many images we are dealing with
sdir=r'/content/drive/My Drive/Colab Notebooks/data/dataset_type_of_plants_new'
files=glob.glob(sdir + '/**/*.jpg', recursive=True)
print (len(files))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 30177

# %% [markdown]
# this is a very large data set with tons of image files. So it might be good to limit the number of files in each
# type of plant to say 150.

# %% [markdown]
# <a id="makedf"></a>
# # <center>Read in images and create a dataframe of image paths and class labels</center>

# %%
# sdir=r'../input/plants-type-datasets/dataset_type_of_plants_new/dataset_type_of_plants_new'
max_images=150 # for any class only include the first 150 images in the dataframe
filepaths=[]
labels=[]
classes=sorted(os.listdir(sdir))
class_count=len(classes)
for klass in classes:
    classpath=os.path.join(sdir, klass)
    flist=sorted(os.listdir(classpath))
    for i, f in enumerate(flist):
        if i < max_images: # limit number of images in a class to 150
            fpath=os.path.join(classpath,f)
            filepaths.append(fpath)
            labels.append(klass)
        else:
            break # after we have found 150 stop iterating through files in the current class to save time
Fseries=pd.Series(filepaths, name='filepaths')
Lseries=pd.Series(labels, name='labels')
df=pd.concat([Fseries, Lseries], axis=1)
# lets split the dataframe into train, test and valid dataframes
train_df, dummy_df=train_test_split(df, train_size=.8, shuffle=True, random_state=123, stratify=df['labels'])
valid_df, test_df=train_test_split(dummy_df, train_size=.5, shuffle=True, random_state=123, stratify=dummy_df['labels'])
print('train_df lenght: ', len(train_df), '  test_df length: ', len(test_df), '  valid_df length: ', len(valid_df))
# get the number of classes and the images count for each class in train_df
print('The number of classes in the dataset is: ', class_count)
groups=train_df.groupby('labels')
print('{0:^30s} {1:^13s}'.format('CLASS', 'IMAGE COUNT'))
countlist=[]
classlist=[]
for label in sorted(list(train_df['labels'].unique())):
    group=groups.get_group(label)
    countlist.append(len(group))
    classlist.append(label)
    print('{0:^30s} {1:^13s}'.format(label, str(len(group))))

# get the classes with the minimum and maximum number of train images
max_value=np.max(countlist)
max_index=countlist.index(max_value)
max_class=classlist[max_index]
min_value=np.min(countlist)
min_index=countlist.index(min_value)
min_class=classlist[min_index]
print(max_class, ' has the most images= ',max_value, ' ', min_class, ' has the least images= ', min_value)
# lets get the average height and width of a sample of the train images
ht=0
wt=0
# select 100 random samples of train_df
train_df_sample=train_df.sample(n=100, random_state=123,axis=0)
for i in range (len(train_df_sample)):
    fpath=train_df_sample['filepaths'].iloc[i]
    img=plt.imread(fpath)
    shape=img.shape
    ht += shape[0] # shape [0] is the image height (rows)
    wt += shape[1] # shape [1] is the image width (columns)
print('average height= ', ht//100, ' average width= ', wt//100, 'aspect ratio= ', ht/wt)
# Out:
# train_df lenght:  3600   test_df length:  450   valid_df length:  450
# The number of classes in the dataset is:  30
#             CLASS               IMAGE COUNT
#            aloevera                 120
#             banana                  120
#            bilimbi                  120
#           cantaloupe                120
#            cassava                  120
#            coconut                  120
#              corn                   120
#            cucumber                 120
#            curcuma                  120
#            eggplant                 120
#            galangal                 120
#             ginger                  120
#             guava                   120
#              kale                   120
#           longbeans                 120
#             mango                   120
#             melon                   120
#             orange                  120
#             paddy                   120
#             papaya                  120
#          peper chili                120
#           pineapple                 120
#             pomelo                  120
#            shallot                  120
#            soybeans                 120
#            spinach                  120
#         sweet potatoes              120
#            tobacco                  120
#           waterapple                120
#           watermelon                120
# aloevera  has the most images=  120   aloevera  has the least images=  120
# average height=  392  average width=  496 aspect ratio=  0.7897567066784822

# %% [markdown]
# <a id="generators"></a>
# # <center>Create the train_gen, test_gen final_test_gen and valid_gen</center>

# %%
img_size=(256, 256)
working_dir =r'./'
batch_size=32
trgen=ImageDataGenerator(horizontal_flip=True,rotation_range=20 )
t_and_v_gen=ImageDataGenerator()
msg='{0:70s} for train generator'.format(' ')
print(msg, '\r', end='') # prints over on the same line
train_gen=trgen.flow_from_dataframe(train_df, x_col='filepaths', y_col='labels', target_size=img_size,
                                   class_mode='categorical', color_mode='rgb', shuffle=True, batch_size=batch_size)
msg='{0:70s} for valid generator'.format(' ')
print(msg, '\r', end='') # prints over on the same line
valid_gen=t_and_v_gen.flow_from_dataframe(valid_df, x_col='filepaths', y_col='labels', target_size=img_size,
                                   class_mode='categorical', color_mode='rgb', shuffle=False, batch_size=batch_size)
# for the test_gen we want to calculate the batch size and test steps such that batch_size X test_steps= number of samples in test set
# this insures that we go through all the sample in the test set exactly once.
length=len(test_df)
test_batch_size=sorted([int(length/n) for n in range(1,length+1) if length % n ==0 and length/n<=80],reverse=True)[0]
test_steps=int(length/test_batch_size)
msg='{0:70s} for test generator'.format(' ')
print(msg, '\r', end='') # prints over on the same line
test_gen=t_and_v_gen.flow_from_dataframe(test_df, x_col='filepaths', y_col='labels', target_size=img_size,
                                   class_mode='categorical', color_mode='rgb', shuffle=False, batch_size=test_batch_size)
# from the generator we can get information we will need later
classes=list(train_gen.class_indices.keys())
class_indices=list(train_gen.class_indices.values())
class_count=len(classes)
labels=test_gen.labels
print ( 'test batch size: ' ,test_batch_size, '  test steps: ', test_steps, ' number of classes : ', class_count)
# Out:
# Found 3600 validated image filenames belonging to 30 classes.
# Found 450 validated image filenames belonging to 30 classes.
# Found 450 validated image filenames belonging to 30 classes.
# test batch size:  75   test steps:  6  number of classes :  30

# %% [markdown]
# <a id="show"></a>
# # <center>Create a function to show example training images</center>

# %%
def show_image_samples(gen ):
    t_dict=gen.class_indices
    classes=list(t_dict.keys())
    images,labels=next(gen) # get a sample batch from the generator
    plt.figure(figsize=(20, 20))
    length=len(labels)
    if length<25:   #show maximum of 25 images
        r=length
    else:
        r=25
    for i in range(r):
        plt.subplot(5, 5, i + 1)
        image=images[i] /255
        plt.imshow(image)
        index=np.argmax(labels[i])
        class_name=classes[index]
        plt.title(class_name, color='blue', fontsize=14)
        plt.axis('off')
    plt.show()

show_image_samples(train_gen )
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# <a id="model"></a>
# # <center>Create a model using Densenet121+EfficientNetV2B2</center>

# %%
img_shape=(img_size[0], img_size[1], 3)

densenet=tf.keras.applications.DenseNet121(input_shape=img_shape,include_top=False, weights='imagenet')
print(densenet.output)

effinet = tf.keras.applications.EfficientNetV2B2(input_shape=img_shape,include_top=False, weights='imagenet')
print(effinet.output)
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 8, 8, 1024), dtype=tf.float32, name=None), name='relu/Relu:0', description="created by layer 'relu'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 8, 8, 1408), dtype=tf.float32, name=None), name='top_activation/IdentityN:0', description="created by layer 'top_activation'")

# %%
def se_block(inputs):
    input_channels = inputs.shape[-1]
    x = tf.keras.layers.GlobalAveragePooling2D()(inputs)
    x = tf.keras.layers.Dense(units=len(train_gen.class_indices.keys()), activation="relu")(x)
    x = tf.keras.layers.Dense(units=input_channels, activation="sigmoid")(x)
    x = tf.reshape(x, [-1, 1, 1, input_channels])
    x = inputs * x
    return x

def dilation_block(inputs,dilation_rates):
    outputs = []
    for dilation_rate in dilation_rates:
        x = tf.keras.layers.Conv2D(filters=len(train_gen.class_indices.keys()), kernel_size=3, strides=1, padding="same", dilation_rate=dilation_rate)(inputs)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.layers.ReLU()(x)
        outputs.append(x)
    x = tf.keras.layers.Concatenate(axis=-1)(outputs)
    return x

# %%
def get_model(base_model):
    x = tf.keras.layers.GlobalAveragePooling2D()(se_block(dilation_block(base_model.output,[2,3,5,7])))
    x=tf.keras.layers.BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001 )(x)
    x = Dense(512, kernel_regularizer = regularizers.l2(l = 0.016),activity_regularizer=regularizers.l1(0.006),
                    bias_regularizer=regularizers.l1(0.006) ,activation='relu')(x)
    x=Dense(256,activation='relu')(x)
    return Dense(128,activation='relu')(x)

x_densenet=get_model(densenet)
x_effnet=get_model(effinet)

# %%
from tensorflow.keras.layers import concatenate
concatenated = concatenate([x_effnet, x_densenet])
bigmodel_prediction = Dense(len(train_gen.class_indices), activation='softmax')(concatenated)
model = Model([effinet.input, densenet.input], bigmodel_prediction)

# %%
lr=.001 # start with this learning rate
model.compile(AdamW(learning_rate=lr, weight_decay=1e-4), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  zero_padding2d_2 (ZeroPadd  (None, 262, 262, 3)          0         ['input_3[0][0]']
#  ing2D)
#
#  conv1/conv (Conv2D)         (None, 128, 128, 64)         9408      ['zero_padding2d_2[0][0]']
#
#  conv1/bn (BatchNormalizati  (None, 128, 128, 64)         256       ['conv1/conv[0][0]']
#  on)
#
#  conv1/relu (Activation)     (None, 128, 128, 64)         0         ['conv1/bn[0][0]']
#
#  zero_padding2d_3 (ZeroPadd  (None, 130, 130, 64)         0         ['conv1/relu[0][0]']
#  ing2D)
#
#  pool1 (MaxPooling2D)        (None, 64, 64, 64)           0         ['zero_padding2d_3[0][0]']
#
#  conv2_block1_0_bn (BatchNo  (None, 64, 64, 64)           256       ['pool1[0][0]']
#  rmalization)
#
#  conv2_block1_0_relu (Activ  (None, 64, 64, 64)           0         ['conv2_block1_0_bn[0][0]']
#  ation)
#
#  conv2_block1_1_conv (Conv2  (None, 64, 64, 128)          8192      ['conv2_block1_0_relu[0][0]']
#  D)
#
#  conv2_block1_1_bn (BatchNo  (None, 64, 64, 128)          512       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, 64, 64, 128)          0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_conv (Conv2  (None, 64, 64, 32)           36864     ['conv2_block1_1_relu[0][0]']
#  D)
#
#  conv2_block1_concat (Conca  (None, 64, 64, 96)           0         ['pool1[0][0]',
#  tenate)                                                             'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNo  (None, 64, 64, 96)           384       ['conv2_block1_concat[0][0]']
#  rmalization)
#
#  conv2_block2_0_relu (Activ  (None, 64, 64, 96)           0         ['conv2_block2_0_bn[0][0]']
#  ation)
#
#  conv2_block2_1_conv (Conv2  (None, 64, 64, 128)          12288     ['conv2_block2_0_relu[0][0]']
#  D)
#
#  conv2_block2_1_bn (BatchNo  (None, 64, 64, 128)          512       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, 64, 64, 128)          0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_conv (Conv2  (None, 64, 64, 32)           36864     ['conv2_block2_1_relu[0][0]']
#  D)
#
#  conv2_block2_concat (Conca  (None, 64, 64, 128)          0         ['conv2_block1_concat[0][0]',
#  tenate)                                                             'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNo  (None, 64, 64, 128)          512       ['conv2_block2_concat[0][0]']
#  rmalization)
#
#  conv2_block3_0_relu (Activ  (None, 64, 64, 128)          0         ['conv2_block3_0_bn[0][0]']
#  ation)
#
#  conv2_block3_1_conv (Conv2  (None, 64, 64, 128)          16384     ['conv2_block3_0_relu[0][0]']
#  D)
#
#  conv2_block3_1_bn (BatchNo  (None, 64, 64, 128)          512       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, 64, 64, 128)          0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_conv (Conv2  (None, 64, 64, 32)           36864     ['conv2_block3_1_relu[0][0]']
#  D)
#
#  conv2_block3_concat (Conca  (None, 64, 64, 160)          0         ['conv2_block2_concat[0][0]',
#  tenate)                                                             'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNo  (None, 64, 64, 160)          640       ['conv2_block3_concat[0][0]']
#  rmalization)
#
#  conv2_block4_0_relu (Activ  (None, 64, 64, 160)          0         ['conv2_block4_0_bn[0][0]']
#  ation)
#
#  conv2_block4_1_conv (Conv2  (None, 64, 64, 128)          20480     ['conv2_block4_0_relu[0][0]']
#  D)
#
#  conv2_block4_1_bn (BatchNo  (None, 64, 64, 128)          512       ['conv2_block4_1_conv[0][0]']
#  rmalization)
#
#  conv2_block4_1_relu (Activ  (None, 64, 64, 128)          0         ['conv2_block4_1_bn[0][0]']
#  ation)
#
#  conv2_block4_2_conv (Conv2  (None, 64, 64, 32)           36864     ['conv2_block4_1_relu[0][0]']
#  D)
#
#  conv2_block4_concat (Conca  (None, 64, 64, 192)          0         ['conv2_block3_concat[0][0]',
#  tenate)                                                             'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNo  (None, 64, 64, 192)          768       ['conv2_block4_concat[0][0]']
#  rmalization)
#
#  conv2_block5_0_relu (Activ  (None, 64, 64, 192)          0         ['conv2_block5_0_bn[0][0]']
#  ation)
#
#  conv2_block5_1_conv (Conv2  (None, 64, 64, 128)          24576     ['conv2_block5_0_relu[0][0]']
#  D)
#
#  conv2_block5_1_bn (BatchNo  (None, 64, 64, 128)          512       ['conv2_block5_1_conv[0][0]']
#  rmalization)
#
#  conv2_block5_1_relu (Activ  (None, 64, 64, 128)          0         ['conv2_block5_1_bn[0][0]']
#  ation)
#
#  conv2_block5_2_conv (Conv2  (None, 64, 64, 32)           36864     ['conv2_block5_1_relu[0][0]']
#  D)
#
#  conv2_block5_concat (Conca  (None, 64, 64, 224)          0         ['conv2_block4_concat[0][0]',
#  tenate)                                                             'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNo  (None, 64, 64, 224)          896       ['conv2_block5_concat[0][0]']
#  rmalization)
#
#  conv2_block6_0_relu (Activ  (None, 64, 64, 224)          0         ['conv2_block6_0_bn[0][0]']
#  ation)
#
#  conv2_block6_1_conv (Conv2  (None, 64, 64, 128)          28672     ['conv2_block6_0_relu[0][0]']
#  D)
#
#  conv2_block6_1_bn (BatchNo  (None, 64, 64, 128)          512       ['conv2_block6_1_conv[0][0]']
#  rmalization)
#
#  conv2_block6_1_relu (Activ  (None, 64, 64, 128)          0         ['conv2_block6_1_bn[0][0]']
#  ation)
#
#  conv2_block6_2_conv (Conv2  (None, 64, 64, 32)           36864     ['conv2_block6_1_relu[0][0]']
#  D)
#
#  conv2_block6_concat (Conca  (None, 64, 64, 256)          0         ['conv2_block5_concat[0][0]',
#  tenate)                                                             'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalizati  (None, 64, 64, 256)          1024      ['conv2_block6_concat[0][0]']
#  on)
#
#  pool2_relu (Activation)     (None, 64, 64, 256)          0         ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)         (None, 64, 64, 128)          32768     ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling  (None, 32, 32, 128)          0         ['pool2_conv[0][0]']
#  2D)
#
#  conv3_block1_0_bn (BatchNo  (None, 32, 32, 128)          512       ['pool2_pool[0][0]']
#  rmalization)
#
#  conv3_block1_0_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block1_0_bn[0][0]']
#  ation)
#
#  conv3_block1_1_conv (Conv2  (None, 32, 32, 128)          16384     ['conv3_block1_0_relu[0][0]']
#  D)
#
#  conv3_block1_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_conv (Conv2  (None, 32, 32, 32)           36864     ['conv3_block1_1_relu[0][0]']
#  D)
#
#  conv3_block1_concat (Conca  (None, 32, 32, 160)          0         ['pool2_pool[0][0]',
#  tenate)                                                             'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNo  (None, 32, 32, 160)          640       ['conv3_block1_concat[0][0]']
#  rmalization)
#
#  conv3_block2_0_relu (Activ  (None, 32, 32, 160)          0         ['conv3_block2_0_bn[0][0]']
#  ation)
#
#  conv3_block2_1_conv (Conv2  (None, 32, 32, 128)          20480     ['conv3_block2_0_relu[0][0]']
#  D)
#
#  conv3_block2_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_conv (Conv2  (None, 32, 32, 32)           36864     ['conv3_block2_1_relu[0][0]']
#  D)
#
#  conv3_block2_concat (Conca  (None, 32, 32, 192)          0         ['conv3_block1_concat[0][0]',
#  tenate)                                                             'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNo  (None, 32, 32, 192)          768       ['conv3_block2_concat[0][0]']
#  rmalization)
#
#  conv3_block3_0_relu (Activ  (None, 32, 32, 192)          0         ['conv3_block3_0_bn[0][0]']
#  ation)
#
#  conv3_block3_1_conv (Conv2  (None, 32, 32, 128)          24576     ['conv3_block3_0_relu[0][0]']
#  D)
#
#  conv3_block3_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_conv (Conv2  (None, 32, 32, 32)           36864     ['conv3_block3_1_relu[0][0]']
#  D)
#
#  conv3_block3_concat (Conca  (None, 32, 32, 224)          0         ['conv3_block2_concat[0][0]',
#  tenate)                                                             'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNo  (None, 32, 32, 224)          896       ['conv3_block3_concat[0][0]']
#  rmalization)
#
#  conv3_block4_0_relu (Activ  (None, 32, 32, 224)          0         ['conv3_block4_0_bn[0][0]']
#  ation)
#
#  conv3_block4_1_conv (Conv2  (None, 32, 32, 128)          28672     ['conv3_block4_0_relu[0][0]']
#  D)
#
#  conv3_block4_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  input_4 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv3_block4_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  rescaling_1 (Rescaling)     (None, 256, 256, 3)          0         ['input_4[0][0]']
#
#  conv3_block4_2_conv (Conv2  (None, 32, 32, 32)           36864     ['conv3_block4_1_relu[0][0]']
#  D)
#
#  normalization_1 (Normaliza  (None, 256, 256, 3)          0         ['rescaling_1[0][0]']
#  tion)
#
#  conv3_block4_concat (Conca  (None, 32, 32, 256)          0         ['conv3_block3_concat[0][0]',
#  tenate)                                                             'conv3_block4_2_conv[0][0]']
#
#  stem_conv (Conv2D)          (None, 128, 128, 32)         864       ['normalization_1[0][0]']
#
#  conv3_block5_0_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv3_block4_concat[0][0]']
#  rmalization)
#
#  stem_bn (BatchNormalizatio  (None, 128, 128, 32)         128       ['stem_conv[0][0]']
#  n)
#
#  conv3_block5_0_relu (Activ  (None, 32, 32, 256)          0         ['conv3_block5_0_bn[0][0]']
#  ation)
#
#  stem_activation (Activatio  (None, 128, 128, 32)         0         ['stem_bn[0][0]']
#  n)
#
#  conv3_block5_1_conv (Conv2  (None, 32, 32, 128)          32768     ['conv3_block5_0_relu[0][0]']
#  D)
#
#  block1a_project_conv (Conv  (None, 128, 128, 16)         4608      ['stem_activation[0][0]']
#  2D)
#
#  conv3_block5_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block5_1_conv[0][0]']
#  rmalization)
#
#  block1a_project_bn (BatchN  (None, 128, 128, 16)         64        ['block1a_project_conv[0][0]']
#  ormalization)
#
#  conv3_block5_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block5_1_bn[0][0]']
#  ation)
#
#  block1a_project_activation  (None, 128, 128, 16)         0         ['block1a_project_bn[0][0]']
#   (Activation)
#
#  conv3_block5_2_conv (Conv2  (None, 32, 32, 32)           36864     ['conv3_block5_1_relu[0][0]']
#  D)
#
#  block1b_project_conv (Conv  (None, 128, 128, 16)         2304      ['block1a_project_activation[0
#  2D)                                                                ][0]']
#
#  conv3_block5_concat (Conca  (None, 32, 32, 288)          0         ['conv3_block4_concat[0][0]',
#  tenate)                                                             'conv3_block5_2_conv[0][0]']
#
#  block1b_project_bn (BatchN  (None, 128, 128, 16)         64        ['block1b_project_conv[0][0]']
#  ormalization)
#
#  conv3_block6_0_bn (BatchNo  (None, 32, 32, 288)          1152      ['conv3_block5_concat[0][0]']
#  rmalization)
#
#  block1b_project_activation  (None, 128, 128, 16)         0         ['block1b_project_bn[0][0]']
#   (Activation)
#
#  conv3_block6_0_relu (Activ  (None, 32, 32, 288)          0         ['conv3_block6_0_bn[0][0]']
#  ation)
#
#  block1b_drop (Dropout)      (None, 128, 128, 16)         0         ['block1b_project_activation[0
#                                                                     ][0]']
#
#  conv3_block6_1_conv (Conv2  (None, 32, 32, 128)          36864     ['conv3_block6_0_relu[0][0]']
#  D)
#
#  block1b_add (Add)           (None, 128, 128, 16)         0         ['block1b_drop[0][0]',
#                                                                      'block1a_project_activation[0
#                                                                     ][0]']
#
#  conv3_block6_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block6_1_conv[0][0]']
#  rmalization)
#
#  block2a_expand_conv (Conv2  (None, 64, 64, 64)           9216      ['block1b_add[0][0]']
#  D)
#
#  conv3_block6_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block6_1_bn[0][0]']
#  ation)
#
#  block2a_expand_bn (BatchNo  (None, 64, 64, 64)           256       ['block2a_expand_conv[0][0]']
#  rmalization)
#
#  conv3_block6_2_conv (Conv2  (None, 32, 32, 32)           36864     ['conv3_block6_1_relu[0][0]']
#  D)
#
#  block2a_expand_activation   (None, 64, 64, 64)           0         ['block2a_expand_bn[0][0]']
#  (Activation)
#
#  conv3_block6_concat (Conca  (None, 32, 32, 320)          0         ['conv3_block5_concat[0][0]',
#  tenate)                                                             'conv3_block6_2_conv[0][0]']
#
#  block2a_project_conv (Conv  (None, 64, 64, 32)           2048      ['block2a_expand_activation[0]
#  2D)                                                                [0]']
#
#  conv3_block7_0_bn (BatchNo  (None, 32, 32, 320)          1280      ['conv3_block6_concat[0][0]']
#  rmalization)
#
#  block2a_project_bn (BatchN  (None, 64, 64, 32)           128       ['block2a_project_conv[0][0]']
#  ormalization)
#
#  conv3_block7_0_relu (Activ  (None, 32, 32, 320)          0         ['conv3_block7_0_bn[0][0]']
#  ation)
#
#  block2b_expand_conv (Conv2  (None, 64, 64, 128)          36864     ['block2a_project_bn[0][0]']
#  D)
#
#  conv3_block7_1_conv (Conv2  (None, 32, 32, 128)          40960     ['conv3_block7_0_relu[0][0]']
#  D)
#
#  block2b_expand_bn (BatchNo  (None, 64, 64, 128)          512       ['block2b_expand_conv[0][0]']
#  rmalization)
#
#  conv3_block7_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block7_1_conv[0][0]']
#  rmalization)
#
#  block2b_expand_activation   (None, 64, 64, 128)          0         ['block2b_expand_bn[0][0]']
#  (Activation)
#
#  conv3_block7_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block7_1_bn[0][0]']
#  ation)
#
#  block2b_project_conv (Conv  (None, 64, 64, 32)           4096      ['block2b_expand_activation[0]
#  2D)                                                                [0]']
#
#  conv3_block7_2_conv (Conv2  (None, 32, 32, 32)           36864     ['conv3_block7_1_relu[0][0]']
#  D)
#
#  block2b_project_bn (BatchN  (None, 64, 64, 32)           128       ['block2b_project_conv[0][0]']
#  ormalization)
#
#  conv3_block7_concat (Conca  (None, 32, 32, 352)          0         ['conv3_block6_concat[0][0]',
#  tenate)                                                             'conv3_block7_2_conv[0][0]']
#
#  block2b_drop (Dropout)      (None, 64, 64, 32)           0         ['block2b_project_bn[0][0]']
#
#  conv3_block8_0_bn (BatchNo  (None, 32, 32, 352)          1408      ['conv3_block7_concat[0][0]']
#  rmalization)
#
#  block2b_add (Add)           (None, 64, 64, 32)           0         ['block2b_drop[0][0]',
#                                                                      'block2a_project_bn[0][0]']
#
#  conv3_block8_0_relu (Activ  (None, 32, 32, 352)          0         ['conv3_block8_0_bn[0][0]']
#  ation)
#
#  block2c_expand_conv (Conv2  (None, 64, 64, 128)          36864     ['block2b_add[0][0]']
#  D)
#
#  conv3_block8_1_conv (Conv2  (None, 32, 32, 128)          45056     ['conv3_block8_0_relu[0][0]']
#  D)
#
#  block2c_expand_bn (BatchNo  (None, 64, 64, 128)          512       ['block2c_expand_conv[0][0]']
#  rmalization)
#
#  conv3_block8_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block8_1_conv[0][0]']
#  rmalization)
#
#  block2c_expand_activation   (None, 64, 64, 128)          0         ['block2c_expand_bn[0][0]']
#  (Activation)
#
#  conv3_block8_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block8_1_bn[0][0]']
#  ation)
#
#  block2c_project_conv (Conv  (None, 64, 64, 32)           4096      ['block2c_expand_activation[0]
#  2D)                                                                [0]']
#
#  conv3_block8_2_conv (Conv2  (None, 32, 32, 32)           36864     ['conv3_block8_1_relu[0][0]']
#  D)
#
#  block2c_project_bn (BatchN  (None, 64, 64, 32)           128       ['block2c_project_conv[0][0]']
#  ormalization)
#
#  conv3_block8_concat (Conca  (None, 32, 32, 384)          0         ['conv3_block7_concat[0][0]',
#  tenate)                                                             'conv3_block8_2_conv[0][0]']
#
#  block2c_drop (Dropout)      (None, 64, 64, 32)           0         ['block2c_project_bn[0][0]']
#
#  conv3_block9_0_bn (BatchNo  (None, 32, 32, 384)          1536      ['conv3_block8_concat[0][0]']
#  rmalization)
#
#  block2c_add (Add)           (None, 64, 64, 32)           0         ['block2c_drop[0][0]',
#                                                                      'block2b_add[0][0]']
#
#  conv3_block9_0_relu (Activ  (None, 32, 32, 384)          0         ['conv3_block9_0_bn[0][0]']
#  ation)
#
#  block3a_expand_conv (Conv2  (None, 32, 32, 128)          36864     ['block2c_add[0][0]']
#  D)
#
#  conv3_block9_1_conv (Conv2  (None, 32, 32, 128)          49152     ['conv3_block9_0_relu[0][0]']
#  D)
#
#  block3a_expand_bn (BatchNo  (None, 32, 32, 128)          512       ['block3a_expand_conv[0][0]']
#  rmalization)
#
#  conv3_block9_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block9_1_conv[0][0]']
#  rmalization)
#
#  block3a_expand_activation   (None, 32, 32, 128)          0         ['block3a_expand_bn[0][0]']
#  (Activation)
#
#  conv3_block9_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block9_1_bn[0][0]']
#  ation)
#
#  block3a_project_conv (Conv  (None, 32, 32, 56)           7168      ['block3a_expand_activation[0]
#  2D)                                                                [0]']
#
#  conv3_block9_2_conv (Conv2  (None, 32, 32, 32)           36864     ['conv3_block9_1_relu[0][0]']
#  D)
#
#  block3a_project_bn (BatchN  (None, 32, 32, 56)           224       ['block3a_project_conv[0][0]']
#  ormalization)
#
#  conv3_block9_concat (Conca  (None, 32, 32, 416)          0         ['conv3_block8_concat[0][0]',
#  tenate)                                                             'conv3_block9_2_conv[0][0]']
#
#  block3b_expand_conv (Conv2  (None, 32, 32, 224)          112896    ['block3a_project_bn[0][0]']
#  D)
#
#  conv3_block10_0_bn (BatchN  (None, 32, 32, 416)          1664      ['conv3_block9_concat[0][0]']
#  ormalization)
#
#  block3b_expand_bn (BatchNo  (None, 32, 32, 224)          896       ['block3b_expand_conv[0][0]']
#  rmalization)
#
#  conv3_block10_0_relu (Acti  (None, 32, 32, 416)          0         ['conv3_block10_0_bn[0][0]']
#  vation)
#
#  block3b_expand_activation   (None, 32, 32, 224)          0         ['block3b_expand_bn[0][0]']
#  (Activation)
#
#  conv3_block10_1_conv (Conv  (None, 32, 32, 128)          53248     ['conv3_block10_0_relu[0][0]']
#  2D)
#
#  block3b_project_conv (Conv  (None, 32, 32, 56)           12544     ['block3b_expand_activation[0]
#  2D)                                                                [0]']
#
#  conv3_block10_1_bn (BatchN  (None, 32, 32, 128)          512       ['conv3_block10_1_conv[0][0]']
#  ormalization)
#
#  block3b_project_bn (BatchN  (None, 32, 32, 56)           224       ['block3b_project_conv[0][0]']
#  ormalization)
#
#  conv3_block10_1_relu (Acti  (None, 32, 32, 128)          0         ['conv3_block10_1_bn[0][0]']
#  vation)
# ...
#
#  block6j_drop (Dropout)      (None, 8, 8, 208)            0         ['block6j_project_bn[0][0]']
#
#  conv5_block16_1_relu (Acti  (None, 8, 8, 128)            0         ['conv5_block16_1_bn[0][0]']
#  vation)
#
#  block6j_add (Add)           (None, 8, 8, 208)            0         ['block6j_drop[0][0]',
#                                                                      'block6i_add[0][0]']
#
#  conv5_block16_2_conv (Conv  (None, 8, 8, 32)             36864     ['conv5_block16_1_relu[0][0]']
#  2D)
#
#  top_conv (Conv2D)           (None, 8, 8, 1408)           292864    ['block6j_add[0][0]']
#
#  conv5_block16_concat (Conc  (None, 8, 8, 1024)           0         ['conv5_block15_concat[0][0]',
#  atenate)                                                            'conv5_block16_2_conv[0][0]']
#
#  top_bn (BatchNormalization  (None, 8, 8, 1408)           5632      ['top_conv[0][0]']
#  )
#
#  bn (BatchNormalization)     (None, 8, 8, 1024)           4096      ['conv5_block16_concat[0][0]']
#
#  top_activation (Activation  (None, 8, 8, 1408)           0         ['top_bn[0][0]']
#  )
#
#  relu (Activation)           (None, 8, 8, 1024)           0         ['bn[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 8, 8, 30)             380190    ['top_activation[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 8, 8, 30)             380190    ['top_activation[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 8, 8, 30)             380190    ['top_activation[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 8, 8, 30)             380190    ['top_activation[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 8, 8, 30)             276510    ['relu[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 8, 8, 30)             276510    ['relu[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 8, 8, 30)             276510    ['relu[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 8, 8, 30)             276510    ['relu[0][0]']
#
#  batch_normalization_15 (Ba  (None, 8, 8, 30)             120       ['conv2d_12[0][0]']
#  tchNormalization)
#
#  batch_normalization_16 (Ba  (None, 8, 8, 30)             120       ['conv2d_13[0][0]']
#  tchNormalization)
#
#  batch_normalization_17 (Ba  (None, 8, 8, 30)             120       ['conv2d_14[0][0]']
#  tchNormalization)
#
#  batch_normalization_18 (Ba  (None, 8, 8, 30)             120       ['conv2d_15[0][0]']
#  tchNormalization)
#
#  batch_normalization_10 (Ba  (None, 8, 8, 30)             120       ['conv2d_8[0][0]']
#  tchNormalization)
#
#  batch_normalization_11 (Ba  (None, 8, 8, 30)             120       ['conv2d_9[0][0]']
#  tchNormalization)
#
#  batch_normalization_12 (Ba  (None, 8, 8, 30)             120       ['conv2d_10[0][0]']
#  tchNormalization)
#
#  batch_normalization_13 (Ba  (None, 8, 8, 30)             120       ['conv2d_11[0][0]']
#  tchNormalization)
#
#  re_lu_12 (ReLU)             (None, 8, 8, 30)             0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  re_lu_13 (ReLU)             (None, 8, 8, 30)             0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  re_lu_14 (ReLU)             (None, 8, 8, 30)             0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  re_lu_15 (ReLU)             (None, 8, 8, 30)             0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  re_lu_8 (ReLU)              (None, 8, 8, 30)             0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  re_lu_9 (ReLU)              (None, 8, 8, 30)             0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  re_lu_10 (ReLU)             (None, 8, 8, 30)             0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  re_lu_11 (ReLU)             (None, 8, 8, 30)             0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  concatenate_4 (Concatenate  (None, 8, 8, 120)            0         ['re_lu_12[0][0]',
#  )                                                                   're_lu_13[0][0]',
#                                                                      're_lu_14[0][0]',
#                                                                      're_lu_15[0][0]']
#
#  concatenate_3 (Concatenate  (None, 8, 8, 120)            0         ['re_lu_8[0][0]',
#  )                                                                   're_lu_9[0][0]',
#                                                                      're_lu_10[0][0]',
#                                                                      're_lu_11[0][0]']
#
#  global_average_pooling2d_7  (None, 120)                  0         ['concatenate_4[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_average_pooling2d_5  (None, 120)                  0         ['concatenate_3[0][0]']
#   (GlobalAveragePooling2D)
#
#  dense_16 (Dense)            (None, 30)                   3630      ['global_average_pooling2d_7[0
#                                                                     ][0]']
#
#  dense_11 (Dense)            (None, 30)                   3630      ['global_average_pooling2d_5[0
#                                                                     ][0]']
#
#  dense_17 (Dense)            (None, 120)                  3720      ['dense_16[0][0]']
#
#  dense_12 (Dense)            (None, 120)                  3720      ['dense_11[0][0]']
#
#  tf.reshape_3 (TFOpLambda)   (None, 1, 1, 120)            0         ['dense_17[0][0]']
#
#  tf.reshape_2 (TFOpLambda)   (None, 1, 1, 120)            0         ['dense_12[0][0]']
#
#  tf.math.multiply_3 (TFOpLa  (None, 8, 8, 120)            0         ['concatenate_4[0][0]',
#  mbda)                                                               'tf.reshape_3[0][0]']
#
#  tf.math.multiply_2 (TFOpLa  (None, 8, 8, 120)            0         ['concatenate_3[0][0]',
#  mbda)                                                               'tf.reshape_2[0][0]']
#
#  global_average_pooling2d_6  (None, 120)                  0         ['tf.math.multiply_3[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_average_pooling2d_4  (None, 120)                  0         ['tf.math.multiply_2[0][0]']
#   (GlobalAveragePooling2D)
#
#  batch_normalization_19 (Ba  (None, 120)                  480       ['global_average_pooling2d_6[0
#  tchNormalization)                                                  ][0]']
#
#  batch_normalization_14 (Ba  (None, 120)                  480       ['global_average_pooling2d_4[0
#  tchNormalization)                                                  ][0]']
#
#  dense_18 (Dense)            (None, 512)                  61952     ['batch_normalization_19[0][0]
#                                                                     ']
#
#  dense_13 (Dense)            (None, 512)                  61952     ['batch_normalization_14[0][0]
#                                                                     ']
#
#  dense_19 (Dense)            (None, 256)                  131328    ['dense_18[0][0]']
#
#  dense_14 (Dense)            (None, 256)                  131328    ['dense_13[0][0]']
#
#  dense_20 (Dense)            (None, 128)                  32896     ['dense_19[0][0]']
#
#  dense_15 (Dense)            (None, 128)                  32896     ['dense_14[0][0]']
#
#  concatenate_5 (Concatenate  (None, 256)                  0         ['dense_20[0][0]',
#  )                                                                   'dense_15[0][0]']
#
#  dense_21 (Dense)            (None, 30)                   7710      ['concatenate_5[0][0]']
#
# ==================================================================================================
# Total params: 18910360 (72.14 MB)
# Trainable params: 18743464 (71.50 MB)
# Non-trainable params: 166896 (651.94 KB)
# __________________________________________________________________________________________________

# %%
def generator_two_img(gen):
    while True:
        X1i = gen.next()
        yield [X1i[0],X1i[0]], X1i[1]

# %% [markdown]
# <a id="callback"></a>
# # <center>Create a custom Keras callback to continue and optionally set LR or halt training</center>
# The LR_ASK callback is a convenient callback that allows you to continue training for ask_epoch more epochs or to halt training.
# If you elect to continue training for more epochs you are given the option to retain the current learning rate (LR) or to
# enter a new value for the learning rate. The form of use is:
# ask=LR_ASK(model,epochs, ask_epoch) where:
# * model is a string which is the name of your compiled model
# * epochs is an integer which is the number of epochs to run specified in model.fit
# * ask_epoch is an integer. If ask_epoch is set to a value say 5 then the model will train for 5 epochs.
#   then the user is ask to enter H to halt training, or enter an inter value. For example if you enter 4
#   training will continue for 4 more epochs to epoch 9 then you will be queried again. Once you enter an
#   integer value you are prompted to press ENTER to continue training using the current learning rate
#   or to enter a new value for the learning rate.
#
#  At the end of training the model weights are set to the weights for the epoch that achieved the lowest validation loss

# %%
class LR_ASK(keras.callbacks.Callback):
    def __init__ (self, model, epochs,  ask_epoch): # initialization of the callback
        super(LR_ASK, self).__init__()
        self.model=model
        self.ask_epoch=ask_epoch
        self.epochs=epochs
        self.ask=True # if True query the user on a specified epoch
        self.lowest_vloss=np.inf
        self.best_weights=self.model.get_weights() # set best weights to model's initial weights
        self.best_epoch=1
        self.plist=[]

    def get_list(self): # define a function to return the list of % validation change
        return (self.plist)
    def on_train_begin(self, logs=None): # this runs on the beginning of training
        if self.ask_epoch == 0:
            print('you set ask_epoch = 0, ask_epoch will be set to 1', flush=True)
            self.ask_epoch=1
        if self.ask_epoch >= self.epochs: # you are running for epochs but ask_epoch>epochs
            print('ask_epoch >= epochs, will train for ', epochs, ' epochs', flush=True)
            self.ask=False # do not query the user
        if self.epochs == 1:
            self.ask=False # running only for 1 epoch so do not query user
        else:
            print('Training will proceed until epoch', ask_epoch,' then you will be asked to')
            print(' enter H to halt training or enter an integer for how many more epochs to run then be asked again')
        self.start_time= time.time() # set the time at which training started

    def on_train_end(self, logs=None):   # runs at the end of training
        print('loading model with weights from epoch ', self.best_epoch)
        self.model.set_weights(self.best_weights) # set the weights of the model to the best weights
        tr_duration=time.time() - self.start_time   # determine how long the training cycle lasted
        hours = tr_duration // 3600
        minutes = (tr_duration - (hours * 3600)) // 60
        seconds = tr_duration - ((hours * 3600) + (minutes * 60))
        msg = f'training elapsed time was {str(hours)} hours, {minutes:4.1f} minutes, {seconds:4.2f} seconds)'
        print (msg, flush=True) # print out training duration time

    def on_epoch_end(self, epoch, logs=None):  # method runs on the end of each epoch
        v_loss=logs.get('val_loss')  # get the validation loss for this epoch
        if epoch >0:
            deltav = self.lowest_vloss- v_loss
            pimprov=(deltav/self.lowest_vloss) * 100
            self.plist.append(pimprov)
        else:
            pimprov=0.0
        if v_loss< self.lowest_vloss:
            self.lowest_vloss=v_loss
            self.best_weights=self.model.get_weights() # set best weights to model's initial weights
            self.best_epoch=epoch + 1

            print (f'\n validation loss of {v_loss:7.4f} is {pimprov:7.4f} % below lowest loss, saving weights from epoch {str(epoch + 1):3s} as best weights')
        else:
            pimprov=abs(pimprov)
            print (f'\n validation loss of {v_loss:7.4f} is {pimprov:7.4f} % above lowest loss of {self.lowest_vloss:7.4f} keeping weights from epoch {str(self.best_epoch)} as best weights')

        if self.ask: # are the conditions right to query the user?
            if epoch + 1 ==self.ask_epoch: # is this epoch the one for quering the user?
                print('\n Enter H to end training or  an integer for the number of additional epochs to run then ask again')
                ans=input()

                if ans == 'H' or ans =='h' or ans == '0': # quit training for these conditions
                    print ('you entered ', ans, ' Training halted on epoch ', epoch+1, ' due to user input\n', flush=True)
                    self.model.stop_training = True # halt training
                else: # user wants to continue training
                    self.ask_epoch += int(ans)
                    if self.ask_epoch > self.epochs:
                        print('\nYou specified maximum epochs of as ', self.epochs, ' cannot train for ', self.ask_epoch, flush =True)
                    else:
                        print ('you entered ', ans, ' Training will continue to epoch ', self.ask_epoch, flush=True)
                        lr=float(tf.keras.backend.get_value(self.model.optimizer.lr)) # get the current learning rate
                        print(f'current LR is  {lr:7.5f}  hit enter to keep  this LR or enter a new LR')
                        ans=input(' ')
                        if ans =='':
                            print (f'keeping current LR of {lr:7.5f}')
                        else:
                            new_lr=float(ans)
                            tf.keras.backend.set_value(self.model.optimizer.lr, new_lr) # set the learning rate in the optimizer
                            print(' changing LR to ', ans)

# %% [markdown]
# <a id="callbacks"></a>
# # <center>Instantiate custom callback

# %%
epochs=60
ask_epoch=10
ask=LR_ASK(model, epochs,  ask_epoch)
#rlronp=tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=2,verbose=1)
#callbacks=[rlronp, ask]
callbacks=[ask]

# %% [markdown]
# <a id="train"></a>
# # <center>Train the model
# ### Note unlike how you are told it is BETTER to make the base model trainable from the outset
# ### It will converge faster and have a lower validation losss. I have done a lot of testing running
# ### both ways.

# %%
history=model.fit(x=generator_two_img(train_gen),  epochs=epochs, verbose=1, validation_data=generator_two_img(valid_gen), validation_steps=valid_gen.n//batch_size,
    validation_batch_size=batch_size,
    steps_per_epoch=train_gen.n//batch_size,
    batch_size=batch_size,)
# Out:
# Epoch 1/60
# 112/112 [==============================] - 193s 623ms/step - loss: 5.7722 - accuracy: 0.3301 - val_loss: 410.5768 - val_accuracy: 0.0357
# Epoch 2/60
# 112/112 [==============================] - 62s 557ms/step - loss: 2.3968 - accuracy: 0.5297 - val_loss: 4516924.5000 - val_accuracy: 0.0335
# Epoch 3/60
# 112/112 [==============================] - 60s 535ms/step - loss: 1.7535 - accuracy: 0.6068 - val_loss: 4397.0938 - val_accuracy: 0.4880
# Epoch 4/60
# 112/112 [==============================] - 59s 524ms/step - loss: 1.4533 - accuracy: 0.6626 - val_loss: 13.2130 - val_accuracy: 0.6651
# Epoch 5/60
# 112/112 [==============================] - 59s 531ms/step - loss: 1.1930 - accuracy: 0.7166 - val_loss: 18.0465 - val_accuracy: 0.5502
# Epoch 6/60
# 112/112 [==============================] - 60s 534ms/step - loss: 1.0940 - accuracy: 0.7455 - val_loss: 1.6078 - val_accuracy: 0.6818
# Epoch 7/60
# 112/112 [==============================] - 60s 533ms/step - loss: 0.9495 - accuracy: 0.7769 - val_loss: 1.2503 - val_accuracy: 0.7225
# Epoch 8/60
# 112/112 [==============================] - 59s 527ms/step - loss: 0.8790 - accuracy: 0.7898 - val_loss: 5.3284 - val_accuracy: 0.6675
# Epoch 9/60
# 112/112 [==============================] - 59s 531ms/step - loss: 0.7745 - accuracy: 0.8111 - val_loss: 1.3494 - val_accuracy: 0.7057
# Epoch 10/60
# 112/112 [==============================] - 59s 530ms/step - loss: 0.7276 - accuracy: 0.8203 - val_loss: 1.0686 - val_accuracy: 0.7416
# Epoch 11/60
# 112/112 [==============================] - 60s 535ms/step - loss: 0.7235 - accuracy: 0.8201 - val_loss: 1.1403 - val_accuracy: 0.7344
# Epoch 12/60
# 112/112 [==============================] - 59s 531ms/step - loss: 0.6384 - accuracy: 0.8459 - val_loss: 5.6909 - val_accuracy: 0.7249
# Epoch 13/60
# 112/112 [==============================] - 60s 536ms/step - loss: 0.5998 - accuracy: 0.8548 - val_loss: 2.3441 - val_accuracy: 0.7344
# Epoch 14/60
# 112/112 [==============================] - 59s 532ms/step - loss: 0.5723 - accuracy: 0.8646 - val_loss: 1.2995 - val_accuracy: 0.7225
# Epoch 15/60
# 112/112 [==============================] - 59s 526ms/step - loss: 0.5699 - accuracy: 0.8601 - val_loss: 1.2194 - val_accuracy: 0.7129
# Epoch 16/60
# 112/112 [==============================] - 60s 534ms/step - loss: 0.5407 - accuracy: 0.8716 - val_loss: 1.1362 - val_accuracy: 0.7608
# Epoch 17/60
# 112/112 [==============================] - 59s 530ms/step - loss: 0.5213 - accuracy: 0.8728 - val_loss: 1.0352 - val_accuracy: 0.7536
# Epoch 18/60
# 112/112 [==============================] - 59s 533ms/step - loss: 0.4326 - accuracy: 0.8907 - val_loss: 1.3037 - val_accuracy: 0.7608
# Epoch 19/60
# 112/112 [==============================] - 59s 530ms/step - loss: 0.4634 - accuracy: 0.8817 - val_loss: 1.2949 - val_accuracy: 0.7464
# Epoch 20/60
# 112/112 [==============================] - 59s 533ms/step - loss: 0.4466 - accuracy: 0.8949 - val_loss: 1.1447 - val_accuracy: 0.7584
# Epoch 21/60
# 112/112 [==============================] - 60s 534ms/step - loss: 0.4246 - accuracy: 0.8927 - val_loss: 1.3385 - val_accuracy: 0.7129
# Epoch 22/60
# 112/112 [==============================] - 59s 530ms/step - loss: 0.4289 - accuracy: 0.8949 - val_loss: 179.5826 - val_accuracy: 0.4617
# Epoch 23/60
# 112/112 [==============================] - 59s 532ms/step - loss: 0.4004 - accuracy: 0.9053 - val_loss: 37.0088 - val_accuracy: 0.6890
# Epoch 24/60
# 112/112 [==============================] - 59s 532ms/step - loss: 0.3760 - accuracy: 0.9061 - val_loss: 4.5707 - val_accuracy: 0.6603
# Epoch 25/60
# 112/112 [==============================] - 60s 536ms/step - loss: 0.3832 - accuracy: 0.9044 - val_loss: 1.1427 - val_accuracy: 0.7464
# Epoch 26/60
# 112/112 [==============================] - 60s 536ms/step - loss: 0.4020 - accuracy: 0.8991 - val_loss: 1.1921 - val_accuracy: 0.7512
# Epoch 27/60
# 112/112 [==============================] - 60s 538ms/step - loss: 0.3732 - accuracy: 0.9025 - val_loss: 1.1694 - val_accuracy: 0.7321
# Epoch 28/60
# 112/112 [==============================] - 60s 534ms/step - loss: 0.3592 - accuracy: 0.9114 - val_loss: 1.1497 - val_accuracy: 0.7584
# Epoch 29/60
# 112/112 [==============================] - 60s 536ms/step - loss: 0.3105 - accuracy: 0.9226 - val_loss: 2.4208 - val_accuracy: 0.7344
# Epoch 30/60
# 112/112 [==============================] - 60s 539ms/step - loss: 0.3403 - accuracy: 0.9089 - val_loss: 1.0490 - val_accuracy: 0.7823
# Epoch 31/60
# 112/112 [==============================] - 60s 540ms/step - loss: 0.3367 - accuracy: 0.9140 - val_loss: 1.1950 - val_accuracy: 0.7464
# Epoch 32/60
# 112/112 [==============================] - 59s 532ms/step - loss: 0.3854 - accuracy: 0.9044 - val_loss: 1.1023 - val_accuracy: 0.7656
# Epoch 33/60
# 112/112 [==============================] - 60s 537ms/step - loss: 0.3037 - accuracy: 0.9238 - val_loss: 1.8980 - val_accuracy: 0.7225
# Epoch 34/60
# 112/112 [==============================] - 60s 537ms/step - loss: 0.3031 - accuracy: 0.9249 - val_loss: 1.2469 - val_accuracy: 0.7656
# Epoch 35/60
# 112/112 [==============================] - 60s 536ms/step - loss: 0.2859 - accuracy: 0.9302 - val_loss: 1.2048 - val_accuracy: 0.7512
# Epoch 36/60
# 112/112 [==============================] - 60s 538ms/step - loss: 0.2802 - accuracy: 0.9249 - val_loss: 1.3793 - val_accuracy: 0.7416
# Epoch 37/60
# 112/112 [==============================] - 60s 538ms/step - loss: 0.2908 - accuracy: 0.9274 - val_loss: 1.7903 - val_accuracy: 0.7512
# Epoch 38/60
# 112/112 [==============================] - 60s 542ms/step - loss: 0.2729 - accuracy: 0.9327 - val_loss: 1.1846 - val_accuracy: 0.7703
# Epoch 39/60
# 112/112 [==============================] - 60s 541ms/step - loss: 0.2961 - accuracy: 0.9327 - val_loss: 1.1541 - val_accuracy: 0.7488
# Epoch 40/60
# 112/112 [==============================] - 60s 541ms/step - loss: 0.2802 - accuracy: 0.9325 - val_loss: 1.2051 - val_accuracy: 0.7464
# Epoch 41/60
# 112/112 [==============================] - 61s 548ms/step - loss: 0.2774 - accuracy: 0.9339 - val_loss: 1.2649 - val_accuracy: 0.7464
# Epoch 42/60
# 112/112 [==============================] - 61s 543ms/step - loss: 0.2681 - accuracy: 0.9327 - val_loss: 1.3063 - val_accuracy: 0.7297
# Epoch 43/60
# 112/112 [==============================] - 60s 541ms/step - loss: 0.2759 - accuracy: 0.9313 - val_loss: 1.1720 - val_accuracy: 0.7225
# Epoch 44/60
# 112/112 [==============================] - 60s 536ms/step - loss: 0.3736 - accuracy: 0.9140 - val_loss: 1.2093 - val_accuracy: 0.7560
# Epoch 45/60
# 112/112 [==============================] - 60s 540ms/step - loss: 0.3092 - accuracy: 0.9280 - val_loss: 1.4048 - val_accuracy: 0.7440
# Epoch 46/60
# 112/112 [==============================] - 60s 535ms/step - loss: 0.2949 - accuracy: 0.9305 - val_loss: 1.1896 - val_accuracy: 0.7656
# Epoch 47/60
# 112/112 [==============================] - 60s 538ms/step - loss: 0.2204 - accuracy: 0.9465 - val_loss: 1.2551 - val_accuracy: 0.7679
# Epoch 48/60
# 112/112 [==============================] - 60s 539ms/step - loss: 0.2336 - accuracy: 0.9470 - val_loss: 1.1852 - val_accuracy: 0.7488
# Epoch 49/60
# 112/112 [==============================] - 61s 543ms/step - loss: 0.2005 - accuracy: 0.9493 - val_loss: 1.1431 - val_accuracy: 0.7727
# Epoch 50/60
# 112/112 [==============================] - 60s 540ms/step - loss: 0.2410 - accuracy: 0.9417 - val_loss: 1.2425 - val_accuracy: 0.7297
# Epoch 51/60
# 112/112 [==============================] - 60s 534ms/step - loss: 0.2389 - accuracy: 0.9442 - val_loss: 1.4742 - val_accuracy: 0.7416
# Epoch 52/60
# 112/112 [==============================] - 60s 540ms/step - loss: 0.2842 - accuracy: 0.9333 - val_loss: 1.7172 - val_accuracy: 0.7344
# Epoch 53/60
# 112/112 [==============================] - 61s 544ms/step - loss: 0.3000 - accuracy: 0.9355 - val_loss: 1.1526 - val_accuracy: 0.7584
# Epoch 54/60
# 112/112 [==============================] - 60s 540ms/step - loss: 0.2327 - accuracy: 0.9448 - val_loss: 1.2059 - val_accuracy: 0.7536
# Epoch 55/60
# 112/112 [==============================] - 61s 544ms/step - loss: 0.2566 - accuracy: 0.9411 - val_loss: 1.3145 - val_accuracy: 0.7344
# Epoch 56/60
# 112/112 [==============================] - 60s 537ms/step - loss: 0.2316 - accuracy: 0.9504 - val_loss: 1.2143 - val_accuracy: 0.7464
# Epoch 57/60
# 112/112 [==============================] - 60s 534ms/step - loss: 0.2408 - accuracy: 0.9423 - val_loss: 1.2545 - val_accuracy: 0.7656
# Epoch 58/60
# 112/112 [==============================] - 61s 547ms/step - loss: 0.2590 - accuracy: 0.9425 - val_loss: 1.2621 - val_accuracy: 0.7392
# Epoch 59/60
# 112/112 [==============================] - 60s 540ms/step - loss: 0.2499 - accuracy: 0.9425 - val_loss: 1.1689 - val_accuracy: 0.7440
# Epoch 60/60
# 112/112 [==============================] - 60s 541ms/step - loss: 0.2634 - accuracy: 0.9378 - val_loss: 1.2794 - val_accuracy: 0.7344

# %% [markdown]
# <a id="plot"></a>
# # <center>Define a function to plot the training data

# %%
def tr_plot(tr_data, start_epoch):
    #Plot the training and validation data
    tacc=tr_data.history['accuracy']
    tloss=tr_data.history['loss']
    vacc=tr_data.history['val_accuracy']
    vloss=tr_data.history['val_loss']
    Epoch_count=len(tacc)+ start_epoch
    Epochs=[]
    for i in range (start_epoch ,Epoch_count):
        Epochs.append(i+1)
    index_loss=np.argmin(vloss)#  this is the epoch with the lowest validation loss
    val_lowest=vloss[index_loss]
    index_acc=np.argmax(vacc)
    acc_highest=vacc[index_acc]
    plt.style.use('fivethirtyeight')
    sc_label='best epoch= '+ str(index_loss+1 +start_epoch)
    vc_label='best epoch= '+ str(index_acc + 1+ start_epoch)
    fig,axes=plt.subplots(nrows=1, ncols=2, figsize=(20,8))
    axes[0].plot(Epochs,tloss, 'r', label='Training loss')
    axes[0].plot(Epochs,vloss,'g',label='Validation loss' )
    axes[0].scatter(index_loss+1 +start_epoch,val_lowest, s=150, c= 'blue', label=sc_label)
    axes[0].set_title('Training and Validation Loss')
    axes[0].set_xlabel('Epochs')
    axes[0].set_ylabel('Loss')
    axes[0].legend()
    axes[1].plot (Epochs,tacc,'r',label= 'Training Accuracy')
    axes[1].plot (Epochs,vacc,'g',label= 'Validation Accuracy')
    axes[1].scatter(index_acc+1 +start_epoch,acc_highest, s=150, c= 'blue', label=vc_label)
    axes[1].set_title('Training and Validation Accuracy')
    axes[1].set_xlabel('Epochs')
    axes[1].set_ylabel('Accuracy')
    axes[1].legend()
    plt.tight_layout
    plt.show()

tr_plot(history,0)

# %% [markdown]
# <a id="result"></a>
# # <center>Make Predictions on the test set</a>
# ### Define a function which takes in a test generator and an integer test_steps
# ### and generates predictions on the test set including a confusion matric
# ### and a classification report

# %%
def prediction_generator(test_images):
    k=0
    for x in test_images:
        k+=len(x[1])
        yield [x[0],x[0]], x[1]
        if(k>=test_images.n):
            break

# %%
def predictor(test_gen, test_steps):
    y_pred= []
    y_true=test_gen.labels
    classes=list(test_gen.class_indices.keys())
    class_count=len(classes)
    errors=0
    preds=model.predict(prediction_generator(test_gen), verbose=1)
    tests=len(preds)
    for i, p in enumerate(preds):
        pred_index=np.argmax(p)
        true_index=test_gen.labels[i]  # labels are integer values
        if pred_index != true_index: # a misclassification has occurred
            errors=errors + 1
            file=test_gen.filenames[i]
        y_pred.append(pred_index)

    acc=( 1-errors/tests) * 100
    print(f'there were {errors} errors in {tests} tests for an accuracy of {acc:6.2f}')
    ypred=np.array(y_pred)
    ytrue=np.array(y_true)
    if class_count <=30:
        cm = confusion_matrix(ytrue, ypred )
        # plot the confusion matrix
        plt.figure(figsize=(12, 8))
        sns.heatmap(cm, annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False)
        plt.xticks(np.arange(class_count)+.5, classes, rotation=90)
        plt.yticks(np.arange(class_count)+.5, classes, rotation=0)
        plt.xlabel("Predicted")
        plt.ylabel("Actual")
        plt.title("Confusion Matrix")
        plt.show()
    clr = classification_report(y_true, y_pred, target_names=classes, digits= 4) # create classification report
    print("Classification Report:\n----------------------\n", clr)
    return errors, tests
errors, tests=predictor(test_gen, test_steps)
# Out:
# 6/6 [==============================] - 197s 38s/step
# there were 121 errors in 450 tests for an accuracy of  73.11
# Classification Report:
# ----------------------
#                  precision    recall  f1-score   support
#
#       aloevera     1.0000    1.0000    1.0000        15
#         banana     0.8000    0.8000    0.8000        15
#        bilimbi     0.8333    0.6667    0.7407        15
#     cantaloupe     0.3077    0.2667    0.2857        15
#        cassava     0.8000    0.5333    0.6400        15
#        coconut     1.0000    0.8667    0.9286        15
#           corn     1.0000    0.8000    0.8889        15
#       cucumber     0.8667    0.8667    0.8667        15
#        curcuma     0.8000    0.8000    0.8000        15
#       eggplant     0.6500    0.8667    0.7429        15
#       galangal     0.6875    0.7333    0.7097        15
#         ginger     0.6471    0.7333    0.6875        15
#          guava     0.5789    0.7333    0.6471        15
#           kale     0.5455    0.4000    0.4615        15
#      longbeans     0.7692    0.6667    0.7143        15
#          mango     0.8333    0.6667    0.7407        15
#          melon     0.0769    0.0667    0.0714        15
#         orange     0.8125    0.8667    0.8387        15
#          paddy     0.7692    0.6667    0.7143        15
#         papaya     0.9231    0.8000    0.8571        15
#    peper chili     0.8235    0.9333    0.8750        15
#      pineapple     0.9286    0.8667    0.8966        15
#         pomelo     0.7222    0.8667    0.7879        15
#        shallot     0.8333    1.0000    0.9091        15
#       soybeans     0.6500    0.8667    0.7429        15
#        spinach     0.6154    0.5333    0.5714        15
# sweet potatoes     0.7143    1.0000    0.8333        15
#        tobacco     0.6250    1.0000    0.7692        15
#     waterapple     0.8000    0.5333    0.6400        15
#     watermelon     0.6667    0.5333    0.5926        15
#
#       accuracy                         0.7311       450
#      macro avg     0.7360    0.7311    0.7251       450
#   weighted avg     0.7360    0.7311    0.7251       450

# %% [markdown]
# We achieved an F1 score of 83,6% which is not to bad considering we limited the number of images in train_df to 120
# images per class and reduced the image size to 200 X 260. This was done to reduce training time at the expense of the
# F1 score.

# %% [markdown]
# <a id="save"></a>
# # <center>Save the model

# %%
import os
os.chdir('/content/drive/My Drive/Colab Notebooks/data/')

subject='plants_concat_Densenet121+EfficientNetV2B0'
acc=str(( 1-errors/tests) * 100)
index=acc.rfind('.')
acc=acc[:index + 3]
save_id= subject + '_' + str(acc) + '.h5'
model_save_loc=os.path.join(working_dir, save_id)
model.save(model_save_loc)
print ('model was saved as ' , model_save_loc )
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# model was saved as  ./plants_concat_Densenet121+EfficientNetV2B0_73.11.h5
